# %%
import pandas as pd
import numpy as np
import os.path
from os import path

pd.set_option('display.max_rows', 500)
if path.exists("/kaggle/input/apache-hadoop-ozone-contributions"):
   os.chdir("/kaggle/input/apache-hadoop-ozone-contributions")

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [20, 10]

# %%
jobs = pd.read_csv("job-runs.csv", names=["name","conclusion","status","begin","end"])
jobs.begin = pd.to_datetime(jobs.begin)
jobs.end = pd.to_datetime(jobs.end)


jobs["duration"] = jobs["end"] - jobs["begin"]
jobs["duration"] = jobs["duration"] / np.timedelta64(1, 'm')

acceptance = jobs[jobs["name"] == "acceptance"]
acceptance = acceptance[acceptance["conclusion"] == "success"]
acceptance
# Out:
#             name conclusion     status                     begin  \
# 6     acceptance    success  completed 2020-06-24 16:00:18+00:00
# 20    acceptance    success  completed 2020-06-24 04:28:02+00:00
# 40    acceptance    success  completed 2020-06-24 09:46:46+00:00
# 62    acceptance    success  completed 2020-06-24 18:40:16+00:00
# 90    acceptance    success  completed 2020-06-24 13:13:22+00:00
# 104   acceptance    success  completed 2020-06-24 12:44:31+00:00
# 124   acceptance    success  completed 2020-06-24 15:58:36+00:00
# 138   acceptance    success  completed 2020-06-24 00:23:53+00:00
# 152   acceptance    success  completed 2020-06-24 14:44:15+00:00
# 166   acceptance    success  completed 2020-06-24 16:57:30+00:00
# 174   acceptance    success  completed 2020-06-24 15:55:55+00:00
# 194   acceptance    success  completed 2020-06-17 06:11:37+00:00
# 208   acceptance    success  completed 2020-06-17 13:21:19+00:00
# ...

# %%
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(20, 12)})
# acceptance["xxx"] = acceptance.begin.dt.to_pydatetime()
# acceptance.begin = acceptance.begin.dt.tz_convert(None)
# acceptance = acceptance.set_index("begin")
acceptance.begin.dtype
# k = acceptance.set_index("xxx")
# k[["duration"]].plot()
# Out:
# datetime64[ns, UTC]

# %%
pd.to_datetime('2018-01-15 3:45pm')
# Out:
# Timestamp('2018-01-15 15:45:00')
