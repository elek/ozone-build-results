# %%
import pandas as pd
import numpy as np
import os.path
from os import path

pd.set_option('display.max_rows', 500)
if path.exists("/kaggle/input/apache-hadoop-ozone-contributions"):
   os.chdir("/kaggle/input/apache-hadoop-ozone-contributions")

# %%
jobs = pd.read_csv("job-runs.csv", parse_dates=["begin","end"],names=["name","status","conclusion","begin","end"])

jobs["duration"] = jobs["end"] - jobs.
# Out:
#                                    name   status conclusion  \
# 0                                  unit  success  completed
# 1                               compile  success  completed
# 2                                   rat  success  completed
# 3                                author  success  completed
# 4                            checkstyle  success  completed
# ...                                 ...      ...        ...
# 7249  integration (filesystem-contract)  success  completed
# 7250                integration (freon)  success  completed
# 7251              integration (hdds-om)  success  completed
# 7252                integration (ozone)  success  completed
# 7253                           coverage  skipped  completed
#
#                          begin                       end
# 0    2020-06-24 15:50:50+00:00 2020-06-24 16:12:15+00:00
# 1    2020-06-24 15:50:51+00:00 2020-06-24 16:00:05+00:00
# 2    2020-06-24 15:50:50+00:00 2020-06-24 15:52:35+00:00
# ...

# %%
repos.sort_values("forks",ascending=False).head(20)
# Out:
#                            name  watchers  stars    size  open_issues  forks
# 1902                      spark     26828  26828  335087          236  22186
# 499                       dubbo     33015  33015   29341          748  21554
# 759           incubator-echarts     42110  42110  163339         1696  14946
# 1045                      kafka     16365  16365  103648          720   8706
# 589                       flink     13637  13637  304896          432   7400
# 45                      airflow     17511  17511   76989          561   6797
# 807             incubator-mxnet     18863  18863   85261         1953   6700
# 664                      hadoop     10663  10663  502422          314   6616
# 1470                   rocketmq     11648  11648    8529          287   6335
# 904          incubator-superset     29360  29360  137972          355   6067
# 2048                  zookeeper      8340   8340  122350          139   5238
# ...
